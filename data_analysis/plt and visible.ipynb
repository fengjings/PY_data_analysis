# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.arange(100)
data1 = np.arange(20)
fig = plt.figure()
data_get = [(20,'first'),
            (40,'second'),
            (80,'third')]
ax = fig.add_subplot(1,1,1)
plt.plot(data,'ko--')
for i,j in data_get:
    ax.annotate(j, xy = (i,data[i]+1),xytext = (i,data[i]+30),
               arrowprops = dict(arrowstyle = 'fancy')
               )

plt.figure()
plt.plot(data1)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
ax.annotate?

# %%
fig, axes = plt.subplots(2,2)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(50))

# plt.subplots_adjust(wspace=0,hspace=0)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
